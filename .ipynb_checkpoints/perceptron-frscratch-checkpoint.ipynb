# %% [markdown]
# # Entrenamiento de un Perceptrón para Reconocer una Compuerta Lógica AND

# %% [markdown]
# ## 1. Introducción
#
# En este notebook, implementaremos un **perceptrón** para que aprenda a reconocer una compuerta lógica **AND**. El perceptrón es un tipo de red neuronal de una sola capa que puede clasificar patrones linealmente separables.

# %% [markdown]
# ## 2. Descripción del Problema
#
# - **Entradas**: Dos valores binarios (0 o 1).
# - **Salidas Esperadas**: El resultado de la compuerta AND (0 o 1).
# - **Arquitectura del Perceptrón**:
#   - **Capa de Entrada**: 2 neuronas (una para cada entrada).
#   - **Capa de Salida**: 1 neurona (salida binaria).
# - **Función de Activación**: Escalón unitario.
# - **Método de Entrenamiento**: Regla de aprendizaje del perceptrón.

# %% [markdown]
# ## 3. Implementación del Código

# %%
import numpy as np

# %%
# Datos de la compuerta AND
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])  # Entradas
y = np.array([0, 0, 0, 1])  # Salidas esperadas

# %%
# Inicialización de pesos y bias
w = np.random.rand(2)  # Pesos iniciales aleatorios
b = np.random.rand()   # Bias inicial aleatorio
learning_rate = 0.1    # Tasa de aprendizaje

# Imprimir valores iniciales
print("Valores iniciales de los pesos y bias:")
print(f"Pesos: w = {w}")
print(f"Bias: b = {b}\n")
# Out:
# Valores iniciales de los pesos y bias:
# Pesos: w = [0.0653689  0.80248449]
# Bias: b = 0.6861171202508038

# %%
# Función de activación (escalón unitario)
def activation(z):
    return 1 if z >= 0 else 0

# %%
# Entrenamiento del perceptrón
epoch = 0
while True:
    epoch += 1
    total_error = 0
    print(f"\n--- Época {epoch} ---")
    
    for i in range(len(X)):
        # Cálculo de la salida del perceptrón
        z = np.dot(X[i], w) + b
        y_pred = activation(z)
        
        # Cálculo del error
        error = y[i] - y_pred
        total_error += error ** 2
        
        # Mostrar operaciones aritméticas
        print(f"\nPatrón {i + 1}: Entrada = {X[i]}, Salida Esperada = {y[i]}, Salida Predicha = {y_pred}")
        print(f"Error = {error}")
        print(f"Pesos actuales: w = {w}, bias = {b}")
        
        # Mostrar operaciones aritméticas en detalle
        print("\nOperaciones aritméticas:")
        print(f"z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b")
        print(f"z = ({w[0]} * {X[i][0]}) + ({w[1]} * {X[i][1]}) + {b}")
        print(f"z = {w[0] * X[i][0]} + {w[1] * X[i][1]} + {b}")
        print(f"z = {z}")
        print(f"y_pred = activation(z) = {y_pred}")
        
        if error != 0:
            # Actualización de pesos y bias
            print("\nActualizando pesos y bias:")
            print(f"w_new = w_current + (learning_rate * error * X[i])")
            print(f"w_new = {w} + ({learning_rate} * {error} * {X[i]})")
            w += learning_rate * error * X[i]
            print(f"Nuevos pesos: w = {w}")
            
            print(f"\nb_new = b_current + (learning_rate * error)")
            print(f"b_new = {b} + ({learning_rate} * {error})")
            b += learning_rate * error
            print(f"Nuevo bias: b = {b}")
    
    # Verificar si el error es 0 para todos los patrones
    if total_error == 0:
        print("\n¡Entrenamiento completado! Error = 0 para todos los patrones.")
        break
# Out:
# --- Época 1 ---
#
# Patrón 1: Entrada = [0 0], Salida Esperada = 0, Salida Predicha = 1
# Error = -1
# Pesos actuales: w = [0.0653689  0.80248449], bias = 0.6861171202508038
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (0.06536890058296063 * 0) + (0.8024844935776054 * 0) + 0.6861171202508038
# z = 0.0 + 0.0 + 0.6861171202508038
# z = 0.6861171202508038
# y_pred = activation(z) = 1
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [0.0653689  0.80248449] + (0.1 * -1 * [0 0])
# Nuevos pesos: w = [0.0653689  0.80248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = 0.6861171202508038 + (0.1 * -1)
# Nuevo bias: b = 0.5861171202508039
#
# Patrón 2: Entrada = [0 1], Salida Esperada = 0, Salida Predicha = 1
# Error = -1
# Pesos actuales: w = [0.0653689  0.80248449], bias = 0.5861171202508039
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (0.06536890058296063 * 0) + (0.8024844935776054 * 1) + 0.5861171202508039
# z = 0.0 + 0.8024844935776054 + 0.5861171202508039
# z = 1.3886016138284094
# y_pred = activation(z) = 1
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [0.0653689  0.80248449] + (0.1 * -1 * [0 1])
# Nuevos pesos: w = [0.0653689  0.70248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = 0.5861171202508039 + (0.1 * -1)
# Nuevo bias: b = 0.4861171202508039
#
# Patrón 3: Entrada = [1 0], Salida Esperada = 0, Salida Predicha = 1
# Error = -1
# Pesos actuales: w = [0.0653689  0.70248449], bias = 0.4861171202508039
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (0.06536890058296063 * 1) + (0.7024844935776055 * 0) + 0.4861171202508039
# z = 0.06536890058296063 + 0.0 + 0.4861171202508039
# z = 0.5514860208337645
# y_pred = activation(z) = 1
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [0.0653689  0.70248449] + (0.1 * -1 * [1 0])
# Nuevos pesos: w = [-0.0346311   0.70248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = 0.4861171202508039 + (0.1 * -1)
# Nuevo bias: b = 0.3861171202508039
#
# Patrón 4: Entrada = [1 1], Salida Esperada = 1, Salida Predicha = 1
# Error = 0
# Pesos actuales: w = [-0.0346311   0.70248449], bias = 0.3861171202508039
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.034631099417039374 * 1) + (0.7024844935776055 * 1) + 0.3861171202508039
# z = -0.034631099417039374 + 0.7024844935776055 + 0.3861171202508039
# z = 1.05397051441137
# y_pred = activation(z) = 1
#
# --- Época 2 ---
#
# Patrón 1: Entrada = [0 0], Salida Esperada = 0, Salida Predicha = 1
# Error = -1
# Pesos actuales: w = [-0.0346311   0.70248449], bias = 0.3861171202508039
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.034631099417039374 * 0) + (0.7024844935776055 * 0) + 0.3861171202508039
# z = -0.0 + 0.0 + 0.3861171202508039
# z = 0.3861171202508039
# y_pred = activation(z) = 1
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [-0.0346311   0.70248449] + (0.1 * -1 * [0 0])
# Nuevos pesos: w = [-0.0346311   0.70248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = 0.3861171202508039 + (0.1 * -1)
# Nuevo bias: b = 0.28611712025080394
#
# Patrón 2: Entrada = [0 1], Salida Esperada = 0, Salida Predicha = 1
# Error = -1
# Pesos actuales: w = [-0.0346311   0.70248449], bias = 0.28611712025080394
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.034631099417039374 * 0) + (0.7024844935776055 * 1) + 0.28611712025080394
# z = -0.0 + 0.7024844935776055 + 0.28611712025080394
# z = 0.9886016138284094
# y_pred = activation(z) = 1
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [-0.0346311   0.70248449] + (0.1 * -1 * [0 1])
# Nuevos pesos: w = [-0.0346311   0.60248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = 0.28611712025080394 + (0.1 * -1)
# Nuevo bias: b = 0.18611712025080393
#
# Patrón 3: Entrada = [1 0], Salida Esperada = 0, Salida Predicha = 1
# Error = -1
# Pesos actuales: w = [-0.0346311   0.60248449], bias = 0.18611712025080393
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.034631099417039374 * 1) + (0.6024844935776055 * 0) + 0.18611712025080393
# z = -0.034631099417039374 + 0.0 + 0.18611712025080393
# z = 0.15148602083376456
# y_pred = activation(z) = 1
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [-0.0346311   0.60248449] + (0.1 * -1 * [1 0])
# Nuevos pesos: w = [-0.1346311   0.60248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = 0.18611712025080393 + (0.1 * -1)
# Nuevo bias: b = 0.08611712025080392
#
# Patrón 4: Entrada = [1 1], Salida Esperada = 1, Salida Predicha = 1
# Error = 0
# Pesos actuales: w = [-0.1346311   0.60248449], bias = 0.08611712025080392
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 1) + (0.6024844935776055 * 1) + 0.08611712025080392
# z = -0.13463109941703938 + 0.6024844935776055 + 0.08611712025080392
# z = 0.55397051441137
# y_pred = activation(z) = 1
#
# --- Época 3 ---
#
# Patrón 1: Entrada = [0 0], Salida Esperada = 0, Salida Predicha = 1
# Error = -1
# Pesos actuales: w = [-0.1346311   0.60248449], bias = 0.08611712025080392
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 0) + (0.6024844935776055 * 0) + 0.08611712025080392
# z = -0.0 + 0.0 + 0.08611712025080392
# z = 0.08611712025080392
# y_pred = activation(z) = 1
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [-0.1346311   0.60248449] + (0.1 * -1 * [0 0])
# Nuevos pesos: w = [-0.1346311   0.60248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = 0.08611712025080392 + (0.1 * -1)
# Nuevo bias: b = -0.013882879749196081
#
# Patrón 2: Entrada = [0 1], Salida Esperada = 0, Salida Predicha = 1
# Error = -1
# Pesos actuales: w = [-0.1346311   0.60248449], bias = -0.013882879749196081
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 0) + (0.6024844935776055 * 1) + -0.013882879749196081
# z = -0.0 + 0.6024844935776055 + -0.013882879749196081
# z = 0.5886016138284094
# y_pred = activation(z) = 1
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [-0.1346311   0.60248449] + (0.1 * -1 * [0 1])
# Nuevos pesos: w = [-0.1346311   0.50248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = -0.013882879749196081 + (0.1 * -1)
# Nuevo bias: b = -0.11388287974919609
#
# Patrón 3: Entrada = [1 0], Salida Esperada = 0, Salida Predicha = 0
# Error = 0
# Pesos actuales: w = [-0.1346311   0.50248449], bias = -0.11388287974919609
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 1) + (0.5024844935776055 * 0) + -0.11388287974919609
# z = -0.13463109941703938 + 0.0 + -0.11388287974919609
# z = -0.24851397916623547
# y_pred = activation(z) = 0
#
# Patrón 4: Entrada = [1 1], Salida Esperada = 1, Salida Predicha = 1
# Error = 0
# Pesos actuales: w = [-0.1346311   0.50248449], bias = -0.11388287974919609
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 1) + (0.5024844935776055 * 1) + -0.11388287974919609
# z = -0.13463109941703938 + 0.5024844935776055 + -0.11388287974919609
# z = 0.25397051441137003
# y_pred = activation(z) = 1
#
# --- Época 4 ---
#
# Patrón 1: Entrada = [0 0], Salida Esperada = 0, Salida Predicha = 0
# Error = 0
# Pesos actuales: w = [-0.1346311   0.50248449], bias = -0.11388287974919609
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 0) + (0.5024844935776055 * 0) + -0.11388287974919609
# z = -0.0 + 0.0 + -0.11388287974919609
# z = -0.11388287974919609
# y_pred = activation(z) = 0
#
# Patrón 2: Entrada = [0 1], Salida Esperada = 0, Salida Predicha = 1
# Error = -1
# Pesos actuales: w = [-0.1346311   0.50248449], bias = -0.11388287974919609
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 0) + (0.5024844935776055 * 1) + -0.11388287974919609
# z = -0.0 + 0.5024844935776055 + -0.11388287974919609
# z = 0.3886016138284094
# y_pred = activation(z) = 1
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [-0.1346311   0.50248449] + (0.1 * -1 * [0 1])
# Nuevos pesos: w = [-0.1346311   0.40248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = -0.11388287974919609 + (0.1 * -1)
# Nuevo bias: b = -0.2138828797491961
#
# Patrón 3: Entrada = [1 0], Salida Esperada = 0, Salida Predicha = 0
# Error = 0
# Pesos actuales: w = [-0.1346311   0.40248449], bias = -0.2138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 1) + (0.4024844935776055 * 0) + -0.2138828797491961
# z = -0.13463109941703938 + 0.0 + -0.2138828797491961
# z = -0.3485139791662355
# y_pred = activation(z) = 0
#
# Patrón 4: Entrada = [1 1], Salida Esperada = 1, Salida Predicha = 1
# Error = 0
# Pesos actuales: w = [-0.1346311   0.40248449], bias = -0.2138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 1) + (0.4024844935776055 * 1) + -0.2138828797491961
# z = -0.13463109941703938 + 0.4024844935776055 + -0.2138828797491961
# z = 0.053970514411370046
# y_pred = activation(z) = 1
#
# --- Época 5 ---
#
# Patrón 1: Entrada = [0 0], Salida Esperada = 0, Salida Predicha = 0
# Error = 0
# Pesos actuales: w = [-0.1346311   0.40248449], bias = -0.2138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 0) + (0.4024844935776055 * 0) + -0.2138828797491961
# z = -0.0 + 0.0 + -0.2138828797491961
# z = -0.2138828797491961
# y_pred = activation(z) = 0
#
# Patrón 2: Entrada = [0 1], Salida Esperada = 0, Salida Predicha = 1
# Error = -1
# Pesos actuales: w = [-0.1346311   0.40248449], bias = -0.2138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 0) + (0.4024844935776055 * 1) + -0.2138828797491961
# z = -0.0 + 0.4024844935776055 + -0.2138828797491961
# z = 0.18860161382840943
# y_pred = activation(z) = 1
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [-0.1346311   0.40248449] + (0.1 * -1 * [0 1])
# Nuevos pesos: w = [-0.1346311   0.30248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = -0.2138828797491961 + (0.1 * -1)
# Nuevo bias: b = -0.3138828797491961
#
# Patrón 3: Entrada = [1 0], Salida Esperada = 0, Salida Predicha = 0
# Error = 0
# Pesos actuales: w = [-0.1346311   0.30248449], bias = -0.3138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 1) + (0.30248449357760554 * 0) + -0.3138828797491961
# z = -0.13463109941703938 + 0.0 + -0.3138828797491961
# z = -0.4485139791662355
# y_pred = activation(z) = 0
#
# Patrón 4: Entrada = [1 1], Salida Esperada = 1, Salida Predicha = 0
# Error = 1
# Pesos actuales: w = [-0.1346311   0.30248449], bias = -0.3138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.13463109941703938 * 1) + (0.30248449357760554 * 1) + -0.3138828797491961
# z = -0.13463109941703938 + 0.30248449357760554 + -0.3138828797491961
# z = -0.14602948558862994
# y_pred = activation(z) = 0
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [-0.1346311   0.30248449] + (0.1 * 1 * [1 1])
# Nuevos pesos: w = [-0.0346311   0.40248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = -0.3138828797491961 + (0.1 * 1)
# Nuevo bias: b = -0.2138828797491961
#
# --- Época 6 ---
#
# Patrón 1: Entrada = [0 0], Salida Esperada = 0, Salida Predicha = 0
# Error = 0
# Pesos actuales: w = [-0.0346311   0.40248449], bias = -0.2138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.034631099417039374 * 0) + (0.4024844935776055 * 0) + -0.2138828797491961
# z = -0.0 + 0.0 + -0.2138828797491961
# z = -0.2138828797491961
# y_pred = activation(z) = 0
#
# Patrón 2: Entrada = [0 1], Salida Esperada = 0, Salida Predicha = 1
# Error = -1
# Pesos actuales: w = [-0.0346311   0.40248449], bias = -0.2138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.034631099417039374 * 0) + (0.4024844935776055 * 1) + -0.2138828797491961
# z = -0.0 + 0.4024844935776055 + -0.2138828797491961
# z = 0.18860161382840943
# y_pred = activation(z) = 1
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [-0.0346311   0.40248449] + (0.1 * -1 * [0 1])
# Nuevos pesos: w = [-0.0346311   0.30248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = -0.2138828797491961 + (0.1 * -1)
# Nuevo bias: b = -0.3138828797491961
#
# Patrón 3: Entrada = [1 0], Salida Esperada = 0, Salida Predicha = 0
# Error = 0
# Pesos actuales: w = [-0.0346311   0.30248449], bias = -0.3138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.034631099417039374 * 1) + (0.30248449357760554 * 0) + -0.3138828797491961
# z = -0.034631099417039374 + 0.0 + -0.3138828797491961
# z = -0.3485139791662355
# y_pred = activation(z) = 0
#
# Patrón 4: Entrada = [1 1], Salida Esperada = 1, Salida Predicha = 0
# Error = 1
# Pesos actuales: w = [-0.0346311   0.30248449], bias = -0.3138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (-0.034631099417039374 * 1) + (0.30248449357760554 * 1) + -0.3138828797491961
# z = -0.034631099417039374 + 0.30248449357760554 + -0.3138828797491961
# z = -0.046029485588629904
# y_pred = activation(z) = 0
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [-0.0346311   0.30248449] + (0.1 * 1 * [1 1])
# Nuevos pesos: w = [0.0653689  0.40248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = -0.3138828797491961 + (0.1 * 1)
# Nuevo bias: b = -0.2138828797491961
#
# --- Época 7 ---
#
# Patrón 1: Entrada = [0 0], Salida Esperada = 0, Salida Predicha = 0
# Error = 0
# Pesos actuales: w = [0.0653689  0.40248449], bias = -0.2138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (0.06536890058296063 * 0) + (0.4024844935776055 * 0) + -0.2138828797491961
# z = 0.0 + 0.0 + -0.2138828797491961
# z = -0.2138828797491961
# y_pred = activation(z) = 0
#
# Patrón 2: Entrada = [0 1], Salida Esperada = 0, Salida Predicha = 1
# Error = -1
# Pesos actuales: w = [0.0653689  0.40248449], bias = -0.2138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (0.06536890058296063 * 0) + (0.4024844935776055 * 1) + -0.2138828797491961
# z = 0.0 + 0.4024844935776055 + -0.2138828797491961
# z = 0.18860161382840943
# y_pred = activation(z) = 1
#
# Actualizando pesos y bias:
# w_new = w_current + (learning_rate * error * X[i])
# w_new = [0.0653689  0.40248449] + (0.1 * -1 * [0 1])
# Nuevos pesos: w = [0.0653689  0.30248449]
#
# b_new = b_current + (learning_rate * error)
# b_new = -0.2138828797491961 + (0.1 * -1)
# Nuevo bias: b = -0.3138828797491961
#
# Patrón 3: Entrada = [1 0], Salida Esperada = 0, Salida Predicha = 0
# Error = 0
# Pesos actuales: w = [0.0653689  0.30248449], bias = -0.3138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (0.06536890058296063 * 1) + (0.30248449357760554 * 0) + -0.3138828797491961
# z = 0.06536890058296063 + 0.0 + -0.3138828797491961
# z = -0.24851397916623547
# y_pred = activation(z) = 0
#
# Patrón 4: Entrada = [1 1], Salida Esperada = 1, Salida Predicha = 1
# Error = 0
# Pesos actuales: w = [0.0653689  0.30248449], bias = -0.3138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (0.06536890058296063 * 1) + (0.30248449357760554 * 1) + -0.3138828797491961
# z = 0.06536890058296063 + 0.30248449357760554 + -0.3138828797491961
# z = 0.053970514411370074
# y_pred = activation(z) = 1
#
# --- Época 8 ---
#
# Patrón 1: Entrada = [0 0], Salida Esperada = 0, Salida Predicha = 0
# Error = 0
# Pesos actuales: w = [0.0653689  0.30248449], bias = -0.3138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (0.06536890058296063 * 0) + (0.30248449357760554 * 0) + -0.3138828797491961
# z = 0.0 + 0.0 + -0.3138828797491961
# z = -0.3138828797491961
# y_pred = activation(z) = 0
#
# Patrón 2: Entrada = [0 1], Salida Esperada = 0, Salida Predicha = 0
# Error = 0
# Pesos actuales: w = [0.0653689  0.30248449], bias = -0.3138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (0.06536890058296063 * 0) + (0.30248449357760554 * 1) + -0.3138828797491961
# z = 0.0 + 0.30248449357760554 + -0.3138828797491961
# z = -0.011398386171590558
# y_pred = activation(z) = 0
#
# Patrón 3: Entrada = [1 0], Salida Esperada = 0, Salida Predicha = 0
# Error = 0
# Pesos actuales: w = [0.0653689  0.30248449], bias = -0.3138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (0.06536890058296063 * 1) + (0.30248449357760554 * 0) + -0.3138828797491961
# z = 0.06536890058296063 + 0.0 + -0.3138828797491961
# z = -0.24851397916623547
# y_pred = activation(z) = 0
#
# Patrón 4: Entrada = [1 1], Salida Esperada = 1, Salida Predicha = 1
# Error = 0
# Pesos actuales: w = [0.0653689  0.30248449], bias = -0.3138828797491961
#
# Operaciones aritméticas:
# z = (w[0] * X[i][0]) + (w[1] * X[i][1]) + b
# z = (0.06536890058296063 * 1) + (0.30248449357760554 * 1) + -0.3138828797491961
# z = 0.06536890058296063 + 0.30248449357760554 + -0.3138828797491961
# z = 0.053970514411370074
# y_pred = activation(z) = 1
#
# ¡Entrenamiento completado! Error = 0 para todos los patrones.

# %%
# Prueba del perceptrón entrenado
print("\n--- Prueba del perceptrón entrenado ---")
for i in range(len(X)):
    z = np.dot(X[i], w) + b
    y_pred = activation(z)
    print(f"Entrada: {X[i]}, Salida Esperada: {y[i]}, Salida Predicha: {y_pred}")
# Out:
# --- Prueba del perceptrón entrenado ---
# Entrada: [0 0], Salida Esperada: 0, Salida Predicha: 0
# Entrada: [0 1], Salida Esperada: 0, Salida Predicha: 0
# Entrada: [1 0], Salida Esperada: 0, Salida Predicha: 0
# Entrada: [1 1], Salida Esperada: 1, Salida Predicha: 1

# %% [markdown]
# ## 4. Conclusión
#
# Este notebook demostró cómo entrenar un perceptrón para reconocer una compuerta lógica AND. El perceptrón aprendió a clasificar correctamente los patrones de entrada después de varias épocas de entrenamiento.

# %% [markdown]
# ## 5. Ejercicios Adicionales
#
# 1. **Modifica los valores de entrada** \( X \) y las salidas esperadas \( y \) para probar otras compuertas lógicas (OR, XOR, etc.).
# 2. **Cambia la tasa de aprendizaje** (`learning_rate`) y observa cómo afecta la convergencia del entrenamiento.
# 3. **Aumenta el número de épocas** y analiza si el perceptrón puede aprender patrones más complejos.
